# %%
import pandas as pd

# %%
airline = pd.read_csv("airline_sentiment.csv")

# %%
airline['airline'].
# Out:
#        Unnamed: 0      tweet_id airline_sentiment         airline  \
# 0               0  5.703060e+17           neutral  Virgin America
# 1               1  5.703010e+17          positive  Virgin America
# 2               2  5.703010e+17           neutral  Virgin America
# 3               3  5.703010e+17          negative  Virgin America
# 4               4  5.703010e+17          negative  Virgin America
# ...           ...           ...               ...             ...
# 14635       14635  5.695880e+17          positive        American
# 14636       14636  5.695870e+17          negative        American
# 14637       14637  5.695870e+17           neutral        American
# 14638       14638  5.695870e+17          negative        American
# 14639       14639  5.695870e+17           neutral        American
#
#                   name  retweet_count  \
# 0              cairdin              0
# 1             jnardino              0
# 2           yvonnalynn              0
# ...
