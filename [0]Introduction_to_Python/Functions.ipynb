# %% [markdown]
# # **Module 0 - Functions**
#
# A PDF version of this notebook is available at [Module 0 - Functions](https://drive.google.com/file/d/1nV8kBx9s5WCtiwBpJAChubeNdIkI6EMG/view?usp=sharing)

# %% [markdown]
# Python has many built-in functions. Some are available by default:

# %%
## length function
s = [1, 2, 3]
len(s)
# Out:
# 3

# %% [markdown]
# Some other functions need to be imported from modules

# %%
from math import sqrt
sqrt(4)
# Out:
# 2.0

# %% [markdown]
# The module can be imported entirely and the function can be retrieved from the module:

# %%
import math
math.exp(1)
# Out:
# 2.718281828459045

# %% [markdown]
# ### *User-Defined Functions*
#
# We can use the ``def`` keyword for a user-defined function. The ``def`` function is followed by the name of the function and in parenthesis the **optional** parameters. The ``return`` keywork is optional.
#
# ```
# def name_of_function(parameter1, parameter2, ...):
#     code block
#     return parameter_to_return
# ```

# %% [markdown]
# The function below has no parameters, and returns `The print function is returning running func_1` when called.

# %%
def func_1():
    print('The print function is returning running func_1')

# %%
## to run the function just use the name followed by () with the optional parameters
func_1()
# Out:
# The print function is returning running func_1

# %% [markdown]
# Notice that to call the function we need to write the function name followed by (), in this example, `func_1()`. Simply using the function name without the () refers to the function, but does not call it:

# %%
func_1
# Out:
# <function __main__.func_1>

# %% [markdown]
# A function can have more than 1 parameter.

# %%
def func_2(a, b):
    return a * b

# %%
func_2(3, 2)
# Out:
# 6

# %%
## You can annotate the variable types by using : followed by var type
def func_3(a: int, b:int):
    return a * b

# %%
func_3(2, 3)
# Out:
# 6

# %%
## Annotating the variable type does not force the argument to have the specific type. It is only for documentation
func_3('a', 3)
# Out:
# 'aaa'

# %%
## Functions are objects which point to a memory location. This means we can copy them to other objects
my_func = func_3
my_func(4,4)
# Out:
# 16

# %% [markdown]
# ### *Lambda Functions*
# The lambda keyword creates a new function, but does not assign it to any specific name - instead it just returns the function object. It is generally used for short 1-line functions

# %%
func_5 = lambda x: x**2

# %%
func_5(3)
# Out:
# 9

# %% [markdown]
# You can use default values. These are called **keyword** arguments, while arguments with no default values are called **positional** arguments. **keyword** arguments are placed at the end of the function definition.

# %%
def func_6(x, y = 2):
  return x/y

# %%
## if y is ommitted, then the default value is used
func_6(4)
# Out:
# 2.0

# %%
## You can call a function by using the parameter names
func_6(y = 3, x = 9)
# Out:
# 3.0
